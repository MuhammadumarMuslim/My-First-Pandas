# %%
import pandas as pd

# %%
series = pd.Series(["BMW", "TOYOTA", "BUGATTI", "FERRARI"])
series
# Out:
# 0        BMW
# 1     TOYOTA
# 2    BUGATTI
# 3    FERRARI
# dtype: object

# %%
colours = pd.Series(["Red", "Blue", "Yellow", "Black"])
colours
# Out:
# 0       Red
# 1      Blue
# 2    Yellow
# 3     Black
# dtype: object

# %%
car_data = pd.DataFrame({"Cars": series, "Clour": colours})
car_data
# Out:
#       Cars   Clour
# 0      BMW     Red
# 1   TOYOTA    Blue
# 2  BUGATTI  Yellow
# 3  FERRARI   Black

# %%
students = pd.read_csv("student_name.csv")
students
# Out:
#     name     surname  age  ball contract       city
# 0  Jasur     Hakimov   17    45    2000$  Samarkand
# 1  Qosim     Husanov   18    76    2100$    Bukhara
# 2   Umar     Jasurov   17    34    1200$   Tashkent
# 3  Husan  Abdullayev   19    29    4000$     Jizzax
# 4  Hasan    Qurbonov   20    69    3600$   Namangan
# 5   Aliy     Hasanov   18    57    2500$    Andijan

# %%
students.to_csv("student_name.csv", index=False)

# %%
children = pd.read_csv("student_name.csv")

# %%
children
# Out:
#     name     surname  age  ball contract       city
# 0  Jasur     Hakimov   17    45    2000$  Samarkand
# 1  Qosim     Husanov   18    76    2100$    Bukhara
# 2   Umar     Jasurov   17    34    1200$   Tashkent
# 3  Husan  Abdullayev   19    29    4000$     Jizzax
# 4  Hasan    Qurbonov   20    69    3600$   Namangan
# 5   Aliy     Hasanov   18    57    2500$    Andijan

# %%
heart_disease = pd.read_csv("https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/heart-disease.csv")

# %%
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
heart_disease.to_csv("big-data", index=False)

# %%
big = pd.read_csv("big-data")
big
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
children
# Out:
#     name     surname  age  ball contract       city
# 0  Jasur     Hakimov   17    45    2000$  Samarkand
# 1  Qosim     Husanov   18    76    2100$    Bukhara
# 2   Umar     Jasurov   17    34    1200$   Tashkent
# 3  Husan  Abdullayev   19    29    4000$     Jizzax
# 4  Hasan    Qurbonov   20    69    3600$   Namangan
# 5   Aliy     Hasanov   18    57    2500$    Andijan

# %%
children.columns
# Out:
# Index(['name', 'surname', 'age', 'ball', 'contract', 'city'], dtype='object')

# %%
children.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
children.describe()
# Out:
#              age       ball
# count   6.000000   6.000000
# mean   18.166667  51.666667
# std     1.169045  18.927934
# min    17.000000  29.000000
# 25%    17.250000  36.750000
# 50%    18.000000  51.000000
# 75%    18.750000  66.000000
# max    20.000000  76.000000

# %%
children.mean()
# Out:
# C:\Users\student.ASTRUM-DOMAIN\AppData\Local\Temp\ipykernel_2852\2664485187.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   children.mean()
# age     18.166667
# ball    51.666667
# dtype: float64

# %%
children.sum()
# Out:
# name                          JasurQosimUmarHusanHasanAliy
# surname     HakimovHusanovJasurovAbdullayevQurbonovHasanov
# age                                                    109
# ball                                                   310
# contract                    2000$2100$1200$4000$3600$2500$
# city         SamarkandBukharaTashkentJizzaxNamanganAndijan
# dtype: object

# %%
children["ball"].sum()
# Out:
# 310

# %%
len(children)
# Out:
# 6

# %%
children
# Out:
#     name     surname  age  ball contract       city
# 0  Jasur     Hakimov   17    45    2000$  Samarkand
# 1  Qosim     Husanov   18    76    2100$    Bukhara
# 2   Umar     Jasurov   17    34    1200$   Tashkent
# 3  Husan  Abdullayev   19    29    4000$     Jizzax
# 4  Hasan    Qurbonov   20    69    3600$   Namangan
# 5   Aliy     Hasanov   18    57    2500$    Andijan

# %%
children.head(3)
# Out:
#     name  surname  age  ball contract       city
# 0  Jasur  Hakimov   17    45    2000$  Samarkand
# 1  Qosim  Husanov   18    76    2100$    Bukhara
# 2   Umar  Jasurov   17    34    1200$   Tashkent

# %%
children.tail(3)
# Out:
#     name     surname  age  ball contract      city
# 3  Husan  Abdullayev   19    29    4000$    Jizzax
# 4  Hasan    Qurbonov   20    69    3600$  Namangan
# 5   Aliy     Hasanov   18    57    2500$   Andijan

# %%
animal = pd.Series(["cow", "dog", "horse", "tiger","zebra"], index=[4,2,8,1,2])
animal
# Out:
# 4      cow
# 2      dog
# 8    horse
# 1    tiger
# 2    zebra
# dtype: object

# %%
animal.loc[2]
# Out:
# 2      dog
# 2    zebra
# dtype: object

# %%
children.loc[4]
# Out:
# name           Hasan
# surname     Qurbonov
# age               20
# ball              69
# contract       3600$
# city        Namangan
# Name: 4, dtype: object

# %%
big.loc[289]
# Out:
# age          55.0
# sex           0.0
# cp            0.0
# trestbps    128.0
# chol        205.0
# fbs           0.0
# restecg       2.0
# thalach     130.0
# exang         1.0
# oldpeak       2.0
# slope         1.0
# ca            1.0
# thal          3.0
# target        0.0
# Name: 289, dtype: float64

# %%
animal.iloc[1]
# Out:
# 'dog'

# %%
children[children["age"] > 18]
# Out:
#     name     surname  age  ball contract      city
# 3  Husan  Abdullayev   19    29    4000$    Jizzax
# 4  Hasan    Qurbonov   20    69    3600$  Namangan

# %%
pd.crosstab(children["name"], children["age"])
# Out:
# age    17  18  19  20
# name
# Aliy    0   1   0   0
# Hasan   0   0   0   1
# Husan   0   0   1   0
# Jasur   1   0   0   0
# Qosim   0   1   0   0
# Umar    1   0   0   0

# %%
children
# Out:
#     name     surname  age  ball contract       city
# 0  Jasur     Hakimov   17    45    2000$  Samarkand
# 1  Qosim     Husanov   18    76    2100$    Bukhara
# 2   Umar     Jasurov   17    34    1200$   Tashkent
# 3  Husan  Abdullayev   19    29    4000$     Jizzax
# 4  Hasan    Qurbonov   20    69    3600$   Namangan
# 5   Aliy     Hasanov   18    57    2500$    Andijan

# %%
children.groupby(["ball"]).mean()
# Out:
#        age
# ball
# 29    19.0
# 34    17.0
# 45    17.0
# 57    18.0
# 69    20.0
# 76    18.0

# %%
children["contract"] = children["contract"].str.replace('[\$\,\.]', '').astype(int)
# Out:
# C:\Users\student.ASTRUM-DOMAIN\AppData\Local\Temp\ipykernel_2852\2346926938.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   children["contract"] = children["contract"].str.replace('[\$\,\.]', '').astype(int)

# %%
children["contract"].plot()
# Out:
# <AxesSubplot:>
